# %%
import pandas as pd

# %%
df=pd.DataFrame([[23,12,22],
                 [17,27,13],
                 [7,9,14]],columns=['Column1','Column2','Column3'])

# %%
df
# Out:
#    Column1  Column2  Column3
# 0       23       12       22
# 1       17       27       13
# 2        7        9       14

# %%
df.T
# Out:
#           0   1   2
# Column1  23  17   7
# Column2  12  27   9
# Column3  22  13  14

# %%
df.at[1,'Column3']
# Out:
# 13

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=3, step=1),
#  Index(['Column1', 'Column2', 'Column3'], dtype='object')]

# %%
df.columns
# Out:
# Index(['Column1', 'Column2', 'Column3'], dtype='object')

# %%
df.dtypes
# Out:
# Column1    int64
# Column2    int64
# Column3    int64
# dtype: object

# %%
df.iat[0,1]
# Out:
# 12

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([[23, 12, 22],
#        [17, 27, 13],
#        [ 7,  9, 14]])

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df.abs()
# Out:
#    Column1  Column2  Column3
# 0       23       12       22
# 1       17       27       13
# 2        7        9       14

# %%
df.add(df)
# Out:
#    Column1  Column2  Column3
# 0       46       24       44
# 1       34       54       26
# 2       14       18       28

# %%
df.all(1)
# Out:
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
df.any(1)
# Out:
# <ipython-input-22-846faba7237c>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df.any(1)
# 0    True
# 1    True
# 2    True
# dtype: bool

# %%
def x(a):
  return a-10
df.apply(x,1)
# Out:
#    Column1  Column2  Column3
# 0       13        2       12
# 1        7       17        3
# 2       -3       -1        4

# %%
df.corr()
# Out:
#           Column1   Column2   Column3
# Column1  1.000000  0.295066  0.718967
# Column2  0.295066  1.000000 -0.451956
# Column3  0.718967 -0.451956  1.000000

# %%
df.cov()
# Out:
#            Column1  Column2    Column3
# Column1  65.333333     23.0  28.666667
# Column2  23.000000     93.0 -21.500000
# Column3  28.666667    -21.5  24.333333

# %%
df.describe()
# Out:
#          Column1    Column2    Column3
# count   3.000000   3.000000   3.000000
# mean   15.666667  16.000000  16.333333
# std     8.082904   9.643651   4.932883
# min     7.000000   9.000000  13.000000
# 25%    12.000000  10.500000  13.500000
# 50%    17.000000  12.000000  14.000000
# 75%    20.000000  19.500000  18.000000
# max    23.000000  27.000000  22.000000

# %%
for (i,v) in df.items():
  print(i,v,sep='\n')
# Out:
# Column1
# 0    23
# 1    17
# 2     7
# Name: Column1, dtype: int64
# Column2
# 0    12
# 1    27
# 2     9
# Name: Column2, dtype: int64
# Column3
# 0    22
# 1    13
# 2    14
# Name: Column3, dtype: int64

# %%
df.keys()
# Out:
# Index(['Column1', 'Column2', 'Column3'], dtype='object')

# %%
print(df.max(1))
print(df.max(0))
# Out:
# 0    23
# 1    27
# 2    14
# dtype: int64
# Column1    23
# Column2    27
# Column3    22
# dtype: int64

# %%
df.mean(0)
# Out:
# Column1    15.666667
# Column2    16.000000
# Column3    16.333333
# dtype: float64

# %%
df.mode(1)
# Out:
#     0   1   2
# 0  12  22  23
# 1  13  17  27
# 2   7   9  14

# %%
df.rank()
# Out:
#    Column1  Column2  Column3
# 0      3.0      2.0      3.0
# 1      2.0      3.0      1.0
# 2      1.0      1.0      2.0

# %%
df.std()
# Out:
# Column1    8.082904
# Column2    9.643651
# Column3    4.932883
# dtype: float64

# %%
df.var()
# Out:
# Column1    65.333333
# Column2    93.000000
# Column3    24.333333
# dtype: float64
